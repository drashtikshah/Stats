# %% [markdown]
# <a href="https://colab.research.google.com/github/drashtikshah/Stats/blob/main/sds_Pracs_3_60009210079.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
import statistics as st

# %%
#Q1
import random
#Genreate random integer values
print(random.randint(0,100))               #Generate random integer between range 0 to 100
# Out:
# 92

# %%
#Q2
#Generate random floating point number '
print(random.uniform(0,100))
# Out:
# 43.336795318347754

# %%
#Q3
population=[]
for i in range(1000):
  p = random.randint(0, 100)
  population.append(p)
print(population)
# Out:
# [86, 32, 26, 94, 32, 66, 67, 90, 100, 16, 76, 99, 61, 92, 82, 53, 39, 82, 91, 74, 6, 13, 41, 18, 8, 92, 56, 33, 67, 15, 8, 55, 61, 100, 69, 86, 89, 16, 26, 63, 96, 94, 36, 66, 30, 13, 55, 10, 34, 31, 10, 13, 17, 27, 4, 96, 13, 82, 81, 98, 7, 21, 83, 54, 61, 83, 9, 9, 20, 85, 90, 15, 56, 73, 77, 5, 98, 100, 17, 2, 53, 82, 86, 95, 35, 99, 55, 94, 3, 25, 63, 86, 92, 18, 24, 28, 93, 70, 93, 98, 13, 12, 15, 59, 83, 67, 72, 80, 46, 73, 0, 78, 35, 63, 96, 21, 3, 88, 13, 90, 96, 7, 17, 17, 40, 27, 52, 78, 84, 27, 5, 1, 46, 67, 1, 3, 88, 55, 14, 30, 9, 35, 32, 62, 0, 21, 26, 58, 10, 68, 27, 84, 51, 69, 0, 40, 32, 55, 63, 86, 31, 98, 32, 4, 97, 37, 9, 72, 12, 47, 28, 0, 92, 11, 96, 21, 32, 81, 26, 25, 27, 35, 78, 13, 43, 97, 21, 76, 18, 97, 80, 42, 48, 22, 16, 9, 83, 52, 29, 65, 49, 5, 43, 78, 25, 6, 84, 91, 63, 60, 85, 42, 14, 86, 41, 33, 69, 96, 64, 33, 34, 15, 61, 46, 100, 16, 69, 63, 6, 57, 2, 32, 61, 27, 38, 47, 40, 66, 22, 74, 100, 28, 45, 13, 45, 73, 66, 80, 2, 6, 26, 3, 44, 30, 10, 87,
# ...

# %%
#Q4
#create histogram
from matplotlib import pyplot as plt
fig,ax = plt.subplots(figsize =(10,7))
ax.hist(population, bin = 500)
print("Histogram of population distribution is shown below: ")
plt.show()

# %%
#Q5
import numpy as np
print("Mean of population is "+ str(np.mean(population)))
print("Variance of the population is "+ str(np.var(population)))
# Out:
# Mean of population is nan
# Variance of the population is nan

# %%
#Q6
import random
n=int(input("Ënter the size of sample you want to draw from your population: "))
sample_data = random.sample(tuple(population), n)
print(sample_data)
print("mean of the sample_data is: ", np.mean(population))
print("Variance of the  random sample_data is: ", np.var(population))
# Out:
# Ënter the size of sample you want to draw from your population: 300
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-44efd826b6c9> in <module>
#       2 import random
#       3 n=int(input("Ënter the size of sample you want to draw from your population: "))
# ----> 4 sample_data = random.sample(tuple(population), n)
#       5 print(sample_data)
#       6 print("mean of the sample_data is: ", np.mean(population))
#
# /usr/lib/python3.7/random.py in sample(self, population, k)
#     319         n = len(population)
#     320         if not 0 <= k <= n:
# --> 321             raise ValueError("Sample larger than population or is negative")
#     322         result = [None] * k
#     323         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
#Q7
import random
n=int(input("enter the size of sample you want to draw from your population: "))
m=int(input("ënter the number of sample you want to draw from your  population: "))
mean_sample = []
for x in range(m):
   #Create a random sample of population with size n.
   sample_data = random.sample(tuple(population), n)
   #Getting the sum of values in the sample then dividing by n:
   mean = np.mean(sample_data)
   #adding this mean to the list of the sample means
   mean_sample.append(mean)
print("mean of the sample mean distribution: "+ str(np.mean(mean_sample)))
print("variance of the sample mean distribution: "+ str(np.var(mean_sample)))
# Out:
# enter the size of sample you want to draw from your population: 1000
# ënter the number of sample you want to draw from your  population: 100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-31a1560c3ce0> in <module>
#       6 for x in range(m):
#       7    #Create a random sample of population with size n.
# ----> 8    sample_data = random.sample(tuple(population), n)
#       9    #Getting the sum of values in the sample then dividing by n:
#      10    mean = np.mean(sample_data)
#
# /usr/lib/python3.7/random.py in sample(self, population, k)
#     319         n = len(population)
#     320         if not 0 <= k <= n:
# --> 321             raise ValueError("Sample larger than population or is negative")
#     322         result = [None] * k
#     323         setsize = 21        # size of a small set minus size of an empty list
#
# ...

# %%
#Q8
print("histogram of the sampling distribution of the sample mean is shown below: ")
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(mean_sample, bins =500)
plt.show()
# Out:
# histogram of the sampling distribution of the sample mean is shown below:

# %%
#Q9
population=[]
for i in range(1000):
  p=random.uniform(0, 100)
  population.append(p)
print(population)
# Out:
# [73.18305063585767, 66.87707885142203, 79.93042736363036, 48.529383633583976, 91.91395828169803, 38.11496569902817, 93.59170335485823, 4.239969618463935, 73.82718842805687, 12.290688300135743, 0.8751392030235894, 12.56834035763773, 9.593388523985624, 76.50190322849384, 89.18392810866858, 11.067330271117104, 38.33446905170602, 97.05313803215714, 36.07417049160977, 45.97681044866907, 45.321750466032206, 8.980565035951793, 92.71982377371457, 42.75695704748455, 75.35880045512488, 82.04994482850543, 78.85999319948377, 62.78279380151566, 91.86213612013243, 43.06856417589565, 13.861571167780873, 63.29922454153846, 41.19586746314645, 11.195929579771956, 21.891312137422215, 34.1098407603036, 67.80360498172753, 24.072846973744365, 40.66988623863561, 5.213225197396165, 29.505500093005942, 72.39344822058065, 44.5040704289288, 87.82698514618212, 92.9025315366221, 35.128735854836556, 52.7656505355593, 34.28952335180744, 82.39353122136112, 70.1696117910962, 99.47953667184177, 38.104447893858605, 98
# ...

# %%
n=int(input("ënter the size of sample you want to draw from your population: "))
sample_data("mean of the sample ")

# %%
#Q15
#generate a normal population
mu=float(input("ënter mean of the normal distrtibution: "))
sigma = float(input("ënter standard devivation of normal distribution:"))
population = np.random.normal(mu, sigma, 1000)

# %%
#Q11
print("mean of pop is "+str(np.mean(population)))
print("variance of the pop is: "+str(np.var(population)))
# Out:
# mean of pop is nan
# variance of the pop is: nan

# %%
population=[]
for i in range(1000):
  p= random.uniform(0, 100)
  population.appned(p)
#print(len(population))
#create histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(mean_sample, bins =500)
print("histogram of the population distribution is shown below: ")
plt.show()
print("mean of the population is "+str(np.mean(population)))
print("variance of the popualtion is "+str(np.var(population)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-e8d719cec439> in <module>
#       2 for i in range(1000):
#       3   p= random.uniform(0, 100)
# ----> 4   population.appned(p)
#       5 #print(len(population))
#       6 #create histogram
#
# AttributeError: 'list' object has no attribute 'appned'

# %%
#Q20
from matplotlib import pyplot as plt
print("histogram of sampling distribution of sample mean is shown below: ")
fig, ax=plt.subplots(figsize =(10,7))
ax.hist(mean_sample, bins=200)
plt.show()
# Out:
# histogram of sampling distribution of sample mean is shown below:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f8144fb787d2> in <module>
#       3 print("histogram of sampling distribution of sample mean is shown below: ")
#       4 fig, ax=plt.subplots(figsize =(10,7))
# ----> 5 ax.hist(mean_sample, bins=200)
#       6 plt.show()
#
# NameError: name 'mean_sample' is not defined

# %%
#23
list_ones=list(np.ones(395,np.int))
list_zeros=list(np.zeors(605, np.int))
population=list_ones + list_zeros
fig, ax = plt.subplot(figsize =(10, 7))
ax.hist(population, bins=3)
print("histogram of population distribution is shown below: ")
plt.show()
n=int(input("enter the size of the sample you want yo draw from the population: "))
m=int(input("enter the number of sample proportion you want to draw from ypur population: "))
sample_proportion =[]
for x in range(m):
  sample_data=random.sample(tuple(population),n)
  proportion = sum(sample_data)/n
  sample_proportion.append(proortion)
print("histogram of the sampling distribution for the sample proprotion is shown below: ")
fig, ax = plt.subplots(figsize =(10, 7))
plt.show()
